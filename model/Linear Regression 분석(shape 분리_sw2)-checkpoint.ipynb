# %%
import pandas as pd
import numpy as np

df = pd.read_csv("biel_train.csv")

# y_temp 결측치 제거
df = df.dropna()

# 'shape'가 'sw2'인 데이터만 df에 저장
df = df[df['shape'] == 'sw2']

# 'shape' 열 삭제
df = df.drop(['shape'], axis=1)

# one-hot encoding (location)
df = pd.get_dummies(df)

columns = list(df.columns.values)
columns.remove('y_temp')

df
# Out:
#       max_tem  tem_rate  height  length  width  W_top  W_side  W_bottom  \
# 1224     48.8      0.73     4.2      20      2     13     8.0       2.7
# 1225     48.8      0.73     4.2      20      2     13     8.0       2.7
# 1226     48.8      0.73     4.2      20      2     13     8.0       2.7
# 1227     48.8      0.73     4.2      20      2     13     8.0       2.7
# 1228     48.8      0.73     4.2      20      2     13     8.0       2.7
# ...       ...       ...     ...     ...    ...    ...     ...       ...
# 3643     48.8      0.73     4.2      20      2     13     8.0       2.7
# 3644     48.8      0.73     4.2      20      2     13     8.0       2.7
# 3645     48.8      0.73     4.2      20      2     13     8.0       2.7
# 3646     48.8      0.73     4.2      20      2     13     8.0       2.7
# 3647     48.8      0.73     4.2      20      2     13     8.0       2.7
#
#       tem_initial  tem_out  days     y_temp  location_bottom  location_center  \
# 1224           15       -5   0.1  18.438821                1                0
# 1225           15       -5   0.2  21.636686                1                0
# 1226           15       -5   0.3  24.608256                1                0
# 1227           15       -5   0.4  27.369711                1                0
# 1228           15       -5   0.5  29.933846                1                0
# ...           ...      ...   ...        ...              ...              ...
# 3643           20       10  26.0  12.436200                0                1
# 3644           20       10  31.0  11.299905                0                1
# 3645           20       10  37.0  10.636728                0                1
# 3646           20       10  43.0  10.313094                0                1
# 3647           20       10  53.0  10.115722                0                1
#
#       location_side1
# 1224               0
# 1225               0
# 1226               0
# 1227               0
# 1228               0
# ...              ...
# 3643               0
# 3644               0
# 3645               0
# 3646               0
# 3647               0
#
# [1200 rows x 15 columns]

# %%
from sklearn.model_selection import train_test_split

X = df[columns]
y = df[['y_temp']]

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (960, 14) (240, 14) (960, 1) (240, 1)

# %%
from sklearn.linear_model import LinearRegression

mlr = LinearRegression()
mlr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# x_test를 넣어 예측

y_predict = mlr.predict(X_test)

# %%
# my_data = [[48.8, 0.73, 4.2, 20, 2, 13, 8.0, 2.7, 20, 10, 26.0, 0, 1, 0]]
# my_predict = mlr.predict(my_data)
# my_predict

# %%
result = y_test[:]
result['y_predict'] = y_predict

result
# Out:
# <ipython-input-6-e8be36990181>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['y_predict'] = y_predict
#          y_temp  y_predict
# 3587  32.931344  39.437500
# 1418   9.756722  23.703125
# 1384  41.765058  43.000000
# 3376  51.949920  39.234375
# 3263  47.266294  38.406250
# ...         ...        ...
# 1488  51.465622  43.562500
# 1332  38.417140  41.093750
# 2709  31.390010  27.156250
# 3602  34.943438  48.796875
# 2507  28.983918  25.250000
#
# [240 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(16,12))
graph = fig.add_subplot(1,1,1)
graph.plot(result['y_temp'], marker='o', color='blue', label='real value')
graph.plot(result['y_predict'], marker='^', color='red', label='predicted value')
graph.set_title('Multiple Linear Regression(SW1)', size=20)
plt.xlabel('index', size=15)
plt.ylabel('y_temp', size=15)
plt.legend(loc='best')

# %%
# import matplotlib.pyplot as plt

# fig = plt.figure()
# graph = fig.add_subplot(1,1,1)
# graph.plot(y_test, marker='o', color='blue', label='실제값')
# graph.plot(y_predict, marker='^', color='red', label='예측값')
# graph.set_title('다중선형회귀 분석 결과(SW1)', size=20)
# plt.xlabel('횟수', size=15)
# plt.ylabel('y_temp(온도)', size=15)
# plt.legend(loc='best')

# %%
# fig = plt.figure()
# graph = fig.add_subplot(1,1,1)
# graph.plot(y_predict, marker='^', color='red', label='예측값')
# graph.set_title('다중선형회귀 분석 결과(SW1)', size=20)
# plt.xlabel('횟수', size=15)
# plt.ylabel('y_temp(온도)', size=15)
# plt.legend(loc='best')

# %%
y_predict
# Out:
# array([[ 39.4375  ],
#        [ 23.703125],
#        [ 43.      ],
#        [ 39.234375],
#        [ 38.40625 ],
#        [ 45.890625],
#        [  8.734375],
#        [ 42.90625 ],
#        [ -4.671875],
#        [ 26.96875 ],
#        [ -8.453125],
#        [ 41.15625 ],
#        [ 43.515625],
#        [ 38.328125],
#        [ 47.84375 ],
#        [ 26.21875 ],
#        [ 26.015625],
#        [ 42.609375],
#        [ 36.53125 ],
#        [ 31.046875],
#        [ 20.703125],
#        [ 45.84375 ],
#        [ 35.65625 ],
#        [ 38.640625],
#        [ 21.671875],
#        [ 24.59375 ],
#        [ 12.625   ],
#        [ 41.375   ],
#        [ 43.28125 ],
#        [ 47.046875],
#        [ 42.28125 ],
#        [ 20.875   ],
#        [ 24.296875],
#        [ 38.65625 ],
#        [ 39.9375  ],
#        [ 21.53125 ],
#        [ 26.015625],
#        [ 24.484375],
#        [ 15.671875],
#        [ 32.796875],
#        [ 43.359375],
#        [ 38.8125  ],
#        [ 41.796875],
#        [ 36.703125],
#        [ 41.453125],
#        [ 42.59375 ],
#        [ 41.71875 ],
#        [ 23.296875],
#        [ 39.625   ],
#        [ 19.8125  ],
#        [ 40.40625 ],
#        [ 44.6875  ],
#        [ 26.328125],
#        [ 16.203125],
#        [ 23.4375  ],
#        [ 23.65625 ],
#        [ 25.21875 ],
#        [ 26.421875],
#        [ 18.140625],
#        [ -1.25    ],
#        [ 41.34375 ],
#        [ 25.546875],
#        [ 35.34375 ],
#        [  3.234375],
#        [ 26.03125 ],
#        [ 46.5625  ],
#        [ 42.03125 ],
#        [ 35.671875],
#        [ 39.328125],
#        [ 28.203125],
#        [ 38.515625],
#        [ 29.296875],
#        [ 33.328125],
#        [ 28.390625],
#        [ 38.59375 ],
#        [ 43.734375],
#        [ 24.09375 ],
#        [ 42.515625],
#        [ 39.25    ],
#        [ 38.734375],
#        [ 42.890625],
#        [ 18.625   ],
#        [ 44.125   ],
#        [ 45.078125],
#        [ 39.5625  ],
#        [ 44.5     ],
#        [ 45.328125],
#        [ 21.34375 ],
#        [ 44.96875 ],
#        [ 27.25    ],
#        [ 42.34375 ],
#        [ 30.046875],
#        [ 36.875   ],
#        [ 41.53125 ],
#        [ 46.515625],
#        [ 32.890625],
#        [ 21.625   ],
#        [ 40.296875],
#        [ 29.265625],
#        [ -6.09375 ],
#        [ 40.484375],
#        [ 43.4375  ],
#        [ 10.828125],
#        [ 11.328125],
#        [ 44.609375],
#        [ 38.125   ],
#        [ 43.65625 ],
#        [-11.5     ],
#        [ 31.15625 ],
#        [ 39.203125],
#        [ 32.265625],
#        [-17.71875 ],
#        [ 37.71875 ],
#        [ 12.921875],
#        [-20.1875  ],
#        [ 43.390625],
#        [ 23.921875],
#        [ 43.0625  ],
#        [ 43.75    ],
#        [ 44.6875  ],
#        [ 44.375   ],
#        [ 35.171875],
#        [ 46.8125  ],
#        [ 41.53125 ],
#        [ 27.46875 ],
#        [ 34.296875],
#        [ 46.046875],
#        [ 41.734375],
#        [ 12.875   ],
#        [ 47.265625],
#        [ 42.78125 ],
#        [ 47.921875],
#        [ 45.546875],
#        [ 41.171875],
#        [ 25.84375 ],
#        [ 26.8125  ],
#        [ 19.421875],
#        [ 24.25    ],
#        [ 42.515625],
#        [ 36.546875],
#        [ 23.9375  ],
#        [ 39.84375 ],
#        [ 42.421875],
#        [ 42.828125],
#        [ 41.84375 ],
#        [ 25.875   ],
#        [ 44.21875 ],
#        [-21.140625],
#        [ 23.765625],
#        [ 41.875   ],
#        [ 28.46875 ],
#        [ 16.1875  ],
#        [ 45.671875],
#        [  9.234375],
#        [ 42.140625],
#        [ 36.3125  ],
#        [ 39.640625],
#        [ 23.921875],
#        [ 44.140625],
#        [ 22.328125],
#        [ 19.59375 ],
#        [ 39.65625 ],
#        [ 45.265625],
#        [  2.46875 ],
#        [ 26.1875  ],
#        [ 27.71875 ],
#        [  6.1875  ],
#        [ 39.375   ],
#        [ 23.078125],
#        [ 46.3125  ],
#        [ 28.96875 ],
#        [  7.140625],
#        [ 24.40625 ],
#        [ 28.515625],
#        [ 24.765625],
#        [ 28.03125 ],
#        [ 39.9375  ],
#        [ 21.046875],
#        [  5.984375],
#        [ 48.609375],
#        [ 31.734375],
#        [ 36.640625],
#        [ 42.125   ],
#        [ 29.828125],
#        [ 42.984375],
#        [ 39.046875],
#        [ 26.515625],
#        [ 25.859375],
#        [ 38.109375],
#        [ 37.625   ],
#        [ 26.859375],
#        [ 42.765625],
#        [ 26.5     ],
#        [ 40.28125 ],
#        [ 48.046875],
#        [ 26.359375],
#        [ 25.46875 ],
#        [ 40.703125],
#        [ 30.125   ],
#        [ 40.484375],
#        [ 17.171875],
#        [ 43.15625 ],
#        [  5.4375  ],
#        [ 27.546875],
#        [ 21.90625 ],
#        [ 22.5     ],
#        [ 27.75    ],
#        [ 48.890625],
#        [  5.6875  ],
#        [ 23.375   ],
#        [ 44.34375 ],
#        [ 38.3125  ],
#        [ 45.953125],
#        [  7.0625  ],
#        [ 37.515625],
#        [ 43.75    ],
#        [ 43.953125],
#        [ 46.875   ],
#        [ 35.734375],
#        [ 46.625   ],
#        [ 44.40625 ],
#        [ 28.625   ],
#        [ 27.484375],
#        [ 24.      ],
#        [ 25.640625],
#        [ 41.90625 ],
#        [ 40.578125],
#        [ 28.578125],
#        [ 46.96875 ],
#        [ 39.296875],
#        [ 30.765625],
#        [ 44.203125],
#        [ 38.71875 ],
#        [ 49.09375 ],
#        [ 49.109375],
#        [ 43.5625  ],
#        [ 41.09375 ],
#        [ 27.15625 ],
#        [ 48.796875],
#        [ 25.25    ]])

# %%
y_test
# Out:
#          y_temp
# 3587  32.931344
# 1418   9.756722
# 1384  41.765058
# 3376  51.949920
# 3263  47.266294
# ...         ...
# 1488  51.465622
# 1332  38.417140
# 2709  31.390010
# 3602  34.943438
# 2507  28.983918
#
# [240 rows x 1 columns]

# %%
fig = plt.figure(figsize=(9,11))
plt.scatter(y_test, y_predict, alpha=0.5)
plt.xlabel("Actual Temp")
plt.ylabel("Predicted Temp")
plt.title("MULTIPLE LINEAR REGRESSION")
a = np.arange(-20,50)
b = a
plt.plot(a, b, 'r')
plt.show()

# %%
print(mlr.score(X_train, y_train))
# Out:
# 0.6649165414114933

# %%
plt.scatter(df['days'], df['y_temp'], alpha=0.5)
plt.xlabel('days')
plt.ylabel('y_temp')
plt.show()
