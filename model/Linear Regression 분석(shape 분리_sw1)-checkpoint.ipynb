# %%
import pandas as pd
import numpy as np

df = pd.read_csv("biel_train.csv")

# y_temp 결측치 제거
df = df.dropna()

# 'shape'가 'sw1'인 데이터만 df에 저장
df = df[df['shape'] == 'sw1']

# 'shape' 열 삭제
df = df.drop(['shape'], axis=1)

# one-hot encoding (location)
df = pd.get_dummies(df)

columns = list(df.columns.values)
columns.remove('y_temp')

df
# Out:
#       max_tem  tem_rate  height  length  width  W_top  W_side  W_bottom  \
# 0        48.8      0.73     4.4      20      2     13    14.0       2.7
# 1        48.8      0.73     4.4      20      2     13    14.0       2.7
# 2        48.8      0.73     4.4      20      2     13    14.0       2.7
# 3        48.8      0.73     4.4      20      2     13    14.0       2.7
# 4        48.8      0.73     4.4      20      2     13    14.0       2.7
# ...       ...       ...     ...     ...    ...    ...     ...       ...
# 4459     48.8      0.73     4.4      20      2     13    14.0       2.7
# 4460     48.8      0.73     4.4      20      2     13    14.0       2.7
# 4461     48.8      0.73     4.4      20      2     13    14.0       2.7
# 4462     48.8      0.73     4.4      20      2     13    14.0       2.7
# 4463     48.8      0.73     4.4      20      2     13    14.0       2.7
#
#       tem_initial  tem_out  days     y_temp  location_bottom  location_center  \
# 0              15       -5   0.0  15.000000                0                0
# 1              15       -5   0.1  16.339477                0                0
# 2              15       -5   0.2  17.124659                0                0
# 3              15       -5   0.3  17.847258                0                0
# 4              15       -5   0.4  18.539062                0                0
# ...           ...      ...   ...        ...              ...              ...
# 4459           20       10  26.0  11.765001                0                0
# 4460           20       10  31.0  10.989847                0                0
# 4461           20       10  37.0  10.524836                0                0
# 4462           20       10  43.0  10.290912                0                0
# 4463           20       10  53.0  10.141336                0                0
#
#       location_side1  location_side2  location_top
# 0                  0               0             1
# 1                  0               0             1
# 2                  0               0             1
# 3                  0               0             1
# 4                  0               0             1
# ...              ...             ...           ...
# 4459               0               1             0
# 4460               0               1             0
# 4461               0               1             0
# 4462               0               1             0
# 4463               0               1             0
#
# [2040 rows x 17 columns]

# %%
from sklearn.model_selection import train_test_split

X = df[columns]
y = df[['y_temp']]

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (1632, 16) (408, 16) (1632, 1) (408, 1)

# %%
from sklearn.linear_model import LinearRegression

mlr = LinearRegression()
mlr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# x_test를 넣어 예측

y_predict = mlr.predict(X_test)

# %%
my_data = [[48.8, 0.73, 4.4, 20, 2, 13, 14.0, 2.7, 20, 10, 27.5, 0, 0, 0, 1, 0]]
my_predict = mlr.predict(my_data)
my_predict
# Out:
# array([[16.1171875]])

# %%
result = y_test[:]
result['y_predict'] = y_predict

result
# Out:
# <ipython-input-204-e8be36990181>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['y_predict'] = y_predict
#          y_temp  y_predict
# 127   21.720876  19.718750
# 973   26.863422  37.468750
# 2902  46.452447  39.656250
# 3199  26.633122  47.136719
# 3037  14.116078  29.425781
# ...         ...        ...
# 92     1.397226  14.878906
# 1204  45.099255  39.882812
# 2874  40.249518  33.828125
# 4335  38.832582  31.937500
# 2976  42.258899  36.078125
#
# [408 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(16,12))
graph = fig.add_subplot(1,1,1)
graph.plot(result['y_temp'], marker='o', color='blue', label='real value')
graph.plot(result['y_predict'], marker='^', color='red', label='predicted value')
graph.set_title('Multiple Linear Regression(SW1)', size=20)
plt.xlabel('index', size=15)
plt.ylabel('y_temp', size=15)
plt.legend(loc='best')

# %%
# import matplotlib.pyplot as plt

# fig = plt.figure()
# graph = fig.add_subplot(1,1,1)
# graph.plot(y_test, marker='o', color='blue', label='실제값')
# graph.plot(y_predict, marker='^', color='red', label='예측값')
# graph.set_title('다중선형회귀 분석 결과(SW1)', size=20)
# plt.xlabel('횟수', size=15)
# plt.ylabel('y_temp(온도)', size=15)
# plt.legend(loc='best')

# %%
# fig = plt.figure()
# graph = fig.add_subplot(1,1,1)
# graph.plot(y_predict, marker='^', color='red', label='예측값')
# graph.set_title('다중선형회귀 분석 결과(SW1)', size=20)
# plt.xlabel('횟수', size=15)
# plt.ylabel('y_temp(온도)', size=15)
# plt.legend(loc='best')

# %%
y_predict
# Out:
# array([[ 19.71875   ],
#        [ 37.46875   ],
#        [ 39.65625   ],
#        [ 47.13671875],
#        [ 29.42578125],
#        [ 20.04296875],
#        [ -1.09765625],
#        [ 24.3359375 ],
#        [  7.87109375],
#        [ 22.1640625 ],
#        [ 22.9921875 ],
#        [ 35.609375  ],
#        [ 26.42578125],
#        [ 35.67578125],
#        [ 42.47265625],
#        [ 25.43359375],
#        [ 23.0390625 ],
#        [ 44.46484375],
#        [ 32.73046875],
#        [ 37.73046875],
#        [ 40.578125  ],
#        [ 29.19921875],
#        [ 19.95703125],
#        [ 33.94140625],
#        [ 37.9375    ],
#        [  7.9140625 ],
#        [ 19.16796875],
#        [ 34.34765625],
#        [ 30.28515625],
#        [ 41.1796875 ],
#        [ 24.46484375],
#        [-12.82421875],
#        [ 19.02734375],
#        [ 22.87890625],
#        [ 26.6640625 ],
#        [ 23.5234375 ],
#        [ 27.94140625],
#        [ 42.1484375 ],
#        [ 22.65234375],
#        [ 23.44140625],
#        [ 23.78515625],
#        [ 19.39453125],
#        [ 43.9765625 ],
#        [ 37.40625   ],
#        [ 11.04296875],
#        [ 29.234375  ],
#        [ 23.01953125],
#        [ 17.76171875],
#        [ 27.4921875 ],
#        [ 43.0859375 ],
#        [ 19.26953125],
#        [ 42.375     ],
#        [ 30.234375  ],
#        [ 21.4375    ],
#        [ 43.33203125],
#        [ 33.87890625],
#        [ 21.59765625],
#        [ 32.828125  ],
#        [ 21.58203125],
#        [ 16.6640625 ],
#        [ 20.76953125],
#        [ 23.83203125],
#        [ 25.8359375 ],
#        [ 32.12890625],
#        [ 25.85546875],
#        [ 37.24609375],
#        [  1.12109375],
#        [ 32.46875   ],
#        [ 24.72265625],
#        [ 23.91015625],
#        [ 37.890625  ],
#        [ 29.265625  ],
#        [ 14.4140625 ],
#        [ 27.33984375],
#        [ 33.69921875],
#        [ 39.54296875],
#        [ 23.1015625 ],
#        [ 14.171875  ],
#        [ 40.04296875],
#        [ 30.703125  ],
#        [ 21.2734375 ],
#        [ 31.109375  ],
#        [ 30.4453125 ],
#        [ 30.8515625 ],
#        [ 38.1015625 ],
#        [ 37.55078125],
#        [ 29.78125   ],
#        [ 21.96875   ],
#        [ 27.22265625],
#        [ 31.3203125 ],
#        [ 17.7109375 ],
#        [ 38.734375  ],
#        [ 13.6484375 ],
#        [ 36.2578125 ],
#        [ 35.04296875],
#        [ 41.015625  ],
#        [ 24.578125  ],
#        [ 26.640625  ],
#        [ 37.328125  ],
#        [ 30.31640625],
#        [ 37.2109375 ],
#        [ 41.890625  ],
#        [ 21.453125  ],
#        [ 27.62109375],
#        [ 20.921875  ],
#        [ 22.23046875],
#        [ 40.7734375 ],
#        [ 17.65234375],
#        [ 22.5546875 ],
#        [ 40.02734375],
#        [ 11.3984375 ],
#        [ 44.3984375 ],
#        [ 19.25      ],
#        [-13.93359375],
#        [ 21.1171875 ],
#        [ 29.9296875 ],
#        [ 31.7421875 ],
#        [ 38.1796875 ],
#        [ 34.9140625 ],
#        [ 26.7578125 ],
#        [ 46.73046875],
#        [ 44.94921875],
#        [ 35.69140625],
#        [ 19.4921875 ],
#        [  1.57421875],
#        [ 24.91796875],
#        [  2.49609375],
#        [ 30.05859375],
#        [ 21.76171875],
#        [ 28.04296875],
#        [ 37.79296875],
#        [ 28.6796875 ],
#        [ 31.02734375],
#        [ 43.41015625],
#        [ 36.7265625 ],
#        [ 38.5546875 ],
#        [ 31.4296875 ],
#        [ 38.66796875],
#        [  3.07421875],
#        [ 23.5078125 ],
#        [ 37.80859375],
#        [ 27.63671875],
#        [ 18.84765625],
#        [ 42.1953125 ],
#        [ 20.8203125 ],
#        [ 42.359375  ],
#        [ 24.19140625],
#        [ 38.57421875],
#        [ 15.1015625 ],
#        [ 24.09375   ],
#        [ 21.11328125],
#        [ 20.3671875 ],
#        [ 45.515625  ],
#        [ 24.9765625 ],
#        [ 29.82421875],
#        [ 12.6171875 ],
#        [ 19.54296875],
#        [ 24.31640625],
#        [ 16.09375   ],
#        [ 19.734375  ],
#        [ 34.89453125],
#        [ 37.77734375],
#        [ 12.4140625 ],
#        [ 27.21484375],
#        [ 36.4375    ],
#        [ 34.234375  ],
#        [ 24.59375   ],
#        [ 19.55859375],
#        [ 29.0078125 ],
#        [ 17.51953125],
#        [ 36.11328125],
#        [ 11.7421875 ],
#        [ 20.64453125],
#        [ 26.015625  ],
#        [ 39.3984375 ],
#        [ 10.6171875 ],
#        [ 33.05078125],
#        [ 36.7109375 ],
#        [ 31.85546875],
#        [ 25.2109375 ],
#        [ 45.19140625],
#        [ 15.671875  ],
#        [ 16.48046875],
#        [  5.59765625],
#        [ 38.0546875 ],
#        [ 27.16015625],
#        [ 41.2265625 ],
#        [ 34.57421875],
#        [ 18.1484375 ],
#        [ 20.22265625],
#        [ 10.51953125],
#        [ 39.203125  ],
#        [ 19.25390625],
#        [ 41.58203125],
#        [ 17.33984375],
#        [ 14.45703125],
#        [ 29.90625   ],
#        [ 23.94921875],
#        [ 22.5390625 ],
#        [ 23.60546875],
#        [ 38.66796875],
#        [ 28.21484375],
#        [ 35.203125  ],
#        [  2.3046875 ],
#        [ 30.23828125],
#        [ 26.73046875],
#        [ 39.81640625],
#        [ 22.00390625],
#        [ 33.65234375],
#        [ 37.390625  ],
#        [ 34.51171875],
#        [ 38.265625  ],
#        [ 31.40234375],
#        [ 39.07421875],
#        [ 40.3671875 ],
#        [ 25.2734375 ],
#        [ 27.0703125 ],
#        [ 20.546875  ],
#        [ 27.69921875],
#        [ -8.55859375],
#        [ 31.64453125],
#        [ 21.79296875],
#        [ 26.7734375 ],
#        [ 21.50390625],
#        [ 21.921875  ],
#        [ 37.48828125],
#        [ 41.2578125 ],
#        [ 38.83203125],
#        [ 46.32421875],
#        [ 36.90234375],
#        [ 35.23828125],
#        [ 11.9609375 ],
#        [ 20.87890625],
#        [ 28.28515625],
#        [ 38.34375   ],
#        [ 38.0546875 ],
#        [ 21.1953125 ],
#        [ 23.921875  ],
#        [ 42.6328125 ],
#        [ 34.8359375 ],
#        [ 32.        ],
#        [ 15.8984375 ],
#        [ 28.7734375 ],
#        [ 42.69921875],
#        [ 41.96875   ],
#        [ 16.4609375 ],
#        [ 23.8671875 ],
#        [ 28.125     ],
#        [ 41.6484375 ],
#        [ -4.734375  ],
#        [ 25.7734375 ],
#        [ 31.20703125],
#        [ 37.875     ],
#        [ 26.59375   ],
#        [ 24.8671875 ],
#        [  0.0546875 ],
#        [ 24.4140625 ],
#        [ 40.82421875],
#        [ 23.19921875],
#        [ 43.16796875],
#        [ 27.40625   ],
#        [ 38.44140625],
#        [ -8.203125  ],
#        [ 25.26953125],
#        [ 36.09765625],
#        [ 28.03515625],
#        [ 38.765625  ],
#        [ 36.14453125],
#        [ 23.36328125],
#        [ 22.734375  ],
#        [ 18.95703125],
#        [ 30.98046875],
#        [-10.38671875],
#        [ 17.62890625],
#        [ -7.34765625],
#        [ 35.48046875],
#        [ 37.06640625],
#        [ 41.79296875],
#        [ 35.140625  ],
#        [-23.3984375 ],
#        [ 33.1796875 ],
#        [ 38.84765625],
#        [ 18.91015625],
#        [ 21.984375  ],
#        [ 36.3515625 ],
#        [ 28.5078125 ],
#        [ -5.015625  ],
#        [ 29.66796875],
#        [ 28.06640625],
#        [ 38.18359375],
#        [ 25.453125  ],
#        [ 41.50390625],
#        [ 34.0234375 ],
#        [ 24.4609375 ],
#        [ 23.99609375],
#        [ 18.1171875 ],
#        [ 16.03125   ],
#        [ 24.55859375],
#        [ 28.859375  ],
#        [ 30.3984375 ],
#        [ 20.62890625],
#        [ 26.1171875 ],
#        [ 14.6796875 ],
#        [ 32.97265625],
#        [ 21.64453125],
#        [ 20.625     ],
#        [ 41.90625   ],
#        [ 19.8984375 ],
#        [ 44.05859375],
#        [-10.453125  ],
#        [ 32.33984375],
#        [ 29.47265625],
#        [ 36.35546875],
#        [ 27.82421875],
#        [ 32.71484375],
#        [ 43.65234375],
#        [ 22.9609375 ],
#        [ 44.5625    ],
#        [ 36.015625  ],
#        [ 35.94921875],
#        [ 27.234375  ],
#        [ 29.60546875],
#        [ 31.67578125],
#        [ 25.67578125],
#        [ 35.55859375],
#        [ 21.6171875 ],
#        [ 42.23046875],
#        [ 27.81640625],
#        [ 24.703125  ],
#        [ 33.68359375],
#        [ 29.89453125],
#        [ 25.59375   ],
#        [ 18.73046875],
#        [ 20.44921875],
#        [ 22.94140625],
#        [ 23.015625  ],
#        [ 42.27734375],
#        [ 35.26953125],
#        [ 30.06640625],
#        [ 26.27734375],
#        [ 24.48046875],
#        [ 33.51953125],
#        [ 31.7578125 ],
#        [ 39.63671875],
#        [ 23.12109375],
#        [ -0.67578125],
#        [ 29.63671875],
#        [ 20.078125  ],
#        [ 35.51171875],
#        [ 33.359375  ],
#        [-17.32421875],
#        [ 26.2421875 ],
#        [ 21.38671875],
#        [ 19.59375   ],
#        [ 17.171875  ],
#        [ 18.21484375],
#        [-21.1484375 ],
#        [  1.15234375],
#        [ 16.84375   ],
#        [ 19.8828125 ],
#        [ 45.2734375 ],
#        [ 21.17578125],
#        [ 26.50390625],
#        [ 12.4296875 ],
#        [ 22.24609375],
#        [ 24.92578125],
#        [ 34.9921875 ],
#        [ 39.15625   ],
#        [ 27.71875   ],
#        [ 21.11328125],
#        [ 24.171875  ],
#        [  6.3515625 ],
#        [ 14.23046875],
#        [ 38.9609375 ],
#        [ 38.66796875],
#        [ 13.0703125 ],
#        [ 39.4140625 ],
#        [ 18.5703125 ],
#        [ 39.07421875],
#        [ 24.515625  ],
#        [ 29.65234375],
#        [ -3.59375   ],
#        [ -4.51171875],
#        [ 43.734375  ],
#        [ 38.296875  ],
#        [ 34.10546875],
#        [ 22.12890625],
#        [ 27.515625  ],
#        [ 42.86328125],
#        [ 16.2421875 ],
#        [ 40.984375  ],
#        [ 45.35546875],
#        [ 32.56640625],
#        [ 19.50390625],
#        [ 18.8671875 ],
#        [ 30.48046875],
#        [ 26.6015625 ],
#        [ 30.04296875],
#        [ 28.609375  ],
#        [ 26.828125  ],
#        [ 24.25390625],
#        [  6.3203125 ],
#        [ 35.640625  ],
#        [ 14.87890625],
#        [ 39.8828125 ],
#        [ 33.828125  ],
#        [ 31.9375    ],
#        [ 36.078125  ]])

# %%
y_test
# Out:
#          y_temp
# 127   21.720876
# 973   26.863422
# 2902  46.452447
# 3199  26.633122
# 3037  14.116078
# ...         ...
# 92     1.397226
# 1204  45.099255
# 2874  40.249518
# 4335  38.832582
# 2976  42.258899
#
# [408 rows x 1 columns]

# %%
fig = plt.figure(figsize=(9,11))
plt.scatter(y_test, y_predict, alpha=0.5)
plt.xlabel("Actual Temp")
plt.ylabel("Predicted Temp")
plt.title("MULTIPLE LINEAR REGRESSION")
a = np.arange(-20,50)
b = a
plt.plot(a, b, 'r')
plt.show()

# %%
print(mlr.score(X_train, y_train))
# Out:
# 0.6948293497787275

# %%
plt.scatter(df['days'], df['y_temp'], alpha=0.5)
plt.xlabel('days')
plt.ylabel('y_temp')
plt.show()
